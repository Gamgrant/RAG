# %% [markdown]
# # CLEAN VERSION

# %% [markdown]
# ### General_Info_and_History_of_Pittsburgh_CMU
# - Grant: ["data/history_wiki_1.txt"] Pittsburgh:https://en.wikipedia.org/wiki/Pittsburgh
# - Grant: ["data/history_wiki_2.txt"] History of Pittsburgh:https://en.wikipedia.org/wiki/History_of_Pittsburgh
# - Grant: ["data/about_cmu_and_cmu_history.txt"] About CMU & CMU History:https://www.cmu.edu/about/
# - Grant: ["data/britannica.txt"] Encyclopedia Brittanica page:https://www.britannica.com/place/Pittsburgh
# - Grant and Nitya: <span style="color:red">[] City of Pittsburgh webpage:https://pittsburghpa.gov/index.html
# - Nitya: <span style="color:red">[] Visit Pittsburgh webpage:https://www.visitpittsburgh.com/
# - Nitya:<span style="color:red">[] Tax Regulations:https://pittsburghpa.gov/finance/tax-forms
# - Nitya: <span style="color:red">[] 2024 Operating Budget:https://apps.pittsburghpa.gov/redtail/images/23255_2024_Operating_Budget.pdf
#
# ### Events_in_Pittsburgh_and_CMU
# - Grant: ["data/event_cal.txt"] Pittsburgh events calendar:https://pittsburgh.events/
# - Grant: ["data/downtown_cal.txt"] Downtown Pittsburgh events calendar:https://downtownpittsburgh.com/events/
# - Grant: ["data/city_paper.txt"] Pittsburgh City Paper events:https://www.pghcitypaper.com/pittsburgh/EventSearch?v=d
# - Grant: ["data/events_cmu.txt"] CMU events calendar:https://events.cmu.edu/
# - Grant: ["data/cmu_campus_major_events.txt"] campus events page:https://www.cmu.edu/engage/alumni/events/campus/index.html
#
# ### Music_and_Culture
# - Grant  ["data/more.txt"]more:https://en.wikipedia.org/wiki/List_of_museums_in_Pittsburgh
# - Grant: ["data/picklesburgh.txt"] Picklesburgh:https://www.picklesburgh.com/
# - Grant: ["data/pittsburgh_taco_festival"] Pittsburgh Taco Fest:https://www.pghtacofest.com/
# - Grant: ["data/pittsburg_restauratnt_week.txt"] Pittsburgh Restaurant Week:https://pittsburghrestaurantweek.com/
# - Grant: ["data/little_italy_days.txt"] Little Italy Days:https://littleitalydays.com/
# - Grant: ["data/banana_split_fest.txt"] Banana Split Fest:https://bananasplitfest.com/
# - Grant: ["data/pittsburgh_symphony.txt"] Symphony:https://www.pittsburghsymphony.org/
# - Nitya: <span style="color:red">[] Opera:https://pittsburghopera.org/
# - Nitya: <span style="color:red">[] Cultural Trust:https://trustarts.org/
# - Nitya: <span style="color:red">[] Carnegie Museums:https://carnegiemuseums.org/
# - Nitya: <span style="color:red">[] Heinz History Center:https://www.heinzhistorycenter.org/
# - Nitya: <span style="color:red">[] The Frick:https://www.thefrickpittsburgh.org/
# - Nitya: <span style="color:red">[] Food Festivals:https://www.visitpittsburgh.com/events-festivals/food-festivals/
#
#
# ### Sports
# - Nitya: <span style="color:red">[] Visit Pittsburgh:https://www.visitpittsburgh.com/things-to-do/pittsburgh-sports-teams/
# - Nitya: <span style="color:red">[] Pirates:https://www.mlb.com/pirates
# - Nitya: <span style="color:red">[] Steelers:https://www.steelers.com/
# - Nitya: <span style="color:red">[] Penguins:https://www.nhl.com/penguins/

# %% [markdown]
# ### For ease of compiling the document here are the guidelines
# - each txt file has =section_start=, =section name="Intro" and =section_end=.
# - tables have the following tags: === Table ===,=== End of Table ===, each table is inside the seciton
# - events are separated with lines that start with ("-----"), each event has at least the following attributes: Title, Date & Time, Location

# %%
pip install langchain langchain_chroma langchain_openai langchain_core langchain_community langchain_mistralai langchain_ollama langchain_pinecone
# Out:
# Requirement already satisfied: langchain in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (0.3.3)
# Requirement already satisfied: langchain_chroma in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (0.1.4)
# Requirement already satisfied: langchain_openai in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (0.2.2)
# Requirement already satisfied: langchain_core in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (0.3.12)
# Requirement already satisfied: langchain_community in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (0.3.2)
# Requirement already satisfied: langchain_mistralai in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (0.2.0)
# Requirement already satisfied: langchain_ollama in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (0.2.0)
# Requirement already satisfied: langchain_pinecone in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (0.2.0)
# Requirement already satisfied: PyYAML>=5.3 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from langchain) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from langchain) (0.3.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from langchain) (0.1.135)
# Requirement already satisfied: numpy<2,>=1 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from langchain) (8.2.3)
# Requirement already satisfied: chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from langchain_chroma) (0.5.15)
# Requirement already satisfied: fastapi<1,>=0.95.2 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from langchain_chroma) (0.115.2)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from langchain_openai) (1.47.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from langchain_openai) (0.7.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from langchain_core) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from langchain_core) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from langchain_core) (4.11.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from langchain_community) (2.6.0)
# Requirement already satisfied: httpx<1,>=0.25.2 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from langchain_mistralai) (0.27.2)
# Requirement already satisfied: httpx-sse<1,>=0.3.1 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from langchain_mistralai) (0.4.0)
# Requirement already satisfied: tokenizers<1,>=0.15.1 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from langchain_mistralai) (0.15.2)
# Requirement already satisfied: ollama<1,>=0.3.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from langchain_ollama) (0.3.3)
# Requirement already satisfied: pinecone-client<6.0.0,>=5.0.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from langchain_pinecone) (5.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.15.4)
# Requirement already satisfied: build>=1.0.3 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.2.2.post1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (0.7.6)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (0.32.0)
# Requirement already satisfied: posthog>=2.4.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (3.7.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.19.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (0.48b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.27.0)
# Requirement already satisfied: pypika>=0.48.9 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (7.4.0)
# Requirement already satisfied: importlib-resources in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.67.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (4.2.0)
# Requirement already satisfied: typer>=0.9.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (0.12.5)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (31.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (5.0.1)
# Requirement already satisfied: orjson>=3.9.12 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (3.10.7)
# Requirement already satisfied: rich>=10.11.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (13.9.2)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: starlette<0.41.0,>=0.37.2 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from fastapi<1,>=0.95.2->langchain_chroma) (0.40.0)
# Requirement already satisfied: anyio in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from httpx<1,>=0.25.2->langchain_mistralai) (4.2.0)
# Requirement already satisfied: certifi in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from httpx<1,>=0.25.2->langchain_mistralai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from httpx<1,>=0.25.2->langchain_mistralai) (1.0.5)
# Requirement already satisfied: idna in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from httpx<1,>=0.25.2->langchain_mistralai) (3.7)
# Requirement already satisfied: sniffio in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from httpx<1,>=0.25.2->langchain_mistralai) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.25.2->langchain_mistralai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain_core) (2.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from openai<2.0.0,>=1.40.0->langchain_openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from openai<2.0.0,>=1.40.0->langchain_openai) (0.5.0)
# Requirement already satisfied: pinecone-plugin-inference<2.0.0,>=1.0.3 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from pinecone-client<6.0.0,>=5.0.0->langchain_pinecone) (1.1.0)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from pinecone-client<6.0.0,>=5.0.0->langchain_pinecone) (0.0.7)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from pinecone-client<6.0.0,>=5.0.0->langchain_pinecone) (1.26.20)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: regex>=2022.1.18 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from tiktoken<1,>=0.7->langchain_openai) (2023.8.8)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from tokenizers<1,>=0.15.1->langchain_mistralai) (0.22.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from anyio->httpx<1,>=0.25.2->langchain_mistralai) (1.2.0)
# Requirement already satisfied: pyproject_hooks in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from build>=1.0.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.2.0)
# Requirement already satisfied: tomli>=1.1.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from build>=1.0.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (2.0.1)
# Requirement already satisfied: filelock in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers<1,>=0.15.1->langchain_mistralai) (3.12.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers<1,>=0.15.1->langchain_mistralai) (2024.3.1)
# Requirement already satisfied: six>=1.9.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (2.22.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (0.9)
# Requirement already satisfied: coloredlogs in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (23.5.26)
# Requirement already satisfied: protobuf in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (4.24.2)
# Requirement already satisfied: sympy in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.12)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.2.14)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (7.0.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.65.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.48b0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (0.48b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.48b0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (0.48b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (0.48b0)
# Requirement already satisfied: opentelemetry-util-http==0.48b0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (0.48b0)
# Requirement already satisfied: setuptools>=16.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (72.1.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.15.0)
# Requirement already satisfied: asgiref~=3.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from opentelemetry-instrumentation-asgi==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (2.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from rich>=10.11.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from rich>=10.11.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (2.16.1)
# Requirement already satisfied: click>=8.0.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.5.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Requirement already satisfied: httptools>=0.5.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (0.6.4)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (0.24.0)
# Requirement already satisfied: websockets>=10.4 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (13.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from yarl<2.0,>=1.0->aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (4.9)
# Requirement already satisfied: zipp>=0.5 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (3.17.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (0.1.2)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from sympy->onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/gman/anaconda3/envs/tensorflow/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (0.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import transformers
import getpass
import os
import langchain
from langchain_core.output_parsers import StrOutputParser
from langchain.prompts import ChatPromptTemplate
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings
from langchain_core.runnables import RunnablePassthrough
from langchain_community.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter, CharacterTextSplitter
from langchain_mistralai import MistralAIEmbeddings, ChatMistralAI
from langchain_ollama import OllamaEmbeddings
from langchain_community.vectorstores import DocArrayInMemorySearch
from langchain_pinecone import PineconeEmbeddings
from langchain.schema import Document  
from langchain import PromptTemplate

# %% [markdown]
# # Create custom loader

# %%
class DynamicHierarchicalTextLoader:
    def __init__(self, categories, name_mappings):
        self.categories = categories  
        self.name_mappings = name_mappings

    def load(self):
        """Load all text files, process events, tables, and sections hierarchically."""
        all_documents = []  
        
        for category, files in self.categories.items():
            for file_path in files:
                if os.path.exists(file_path):
                    descriptive_name = self.name_mappings.get(file_path, "")  
                    file_data = self._load_single_file(file_path, category, descriptive_name)
                    all_documents.extend(file_data)  

        return all_documents

    def _load_single_file(self, file_path, category, descriptive_name):
        """Load a single file and process sections, tables, and events."""
        documents = []
        current_section = None
        current_content = []
        inside_event = False
        inside_table = False
        table_content = []
        event_content = {}

        with open(file_path, 'r', encoding='utf-8') as file:
            lines = file.readlines()

        for i, line in enumerate(lines):
            line = line.strip()  
            if line.startswith('=section_start='):
                if current_section and current_content:
                    documents.extend(self._create_text_chunks(current_section, current_content, category))
                current_content = []
            elif line.startswith('=section name='):
                section_name = line.split('=section name="')[1].strip('\"')
                current_section = f"{descriptive_name}: {section_name}" 
            elif line.startswith('=== Table ==='):
                inside_table = True
                table_content = []
            elif line.startswith('=== End of Table ==='):
                inside_table = False
                documents.append(self._create_table_chunk(current_section, table_content, category))
            elif inside_table:
                table_content.append(line)
            elif line.startswith('-----'):
                if not inside_event:
                    inside_event = True
                    event_content = {"type": "event", "Title": None, "Date & Time": None, "Location": None, "Description": ""}
                else:
                    inside_event = False
                    documents.append(self._create_event_chunk(current_section, event_content, category))
            elif inside_event:
                if line.startswith("Title:"):
                    event_content["Title"] = line.split("Title:")[1].strip()
                elif line.startswith("Date & Time:"):
                    event_content["Date & Time"] = line.split("Date & Time:")[1].strip()
                elif line.startswith("Location:"):
                    event_content["Location"] = line.split("Location:")[1].strip()
                else:
                    event_content["Description"] += line + "\n"
            elif line.startswith('=section_end='):
                if current_section and current_content:
                    documents.extend(self._create_text_chunks(current_section, current_content, category))
                current_section = None
                current_content = []
            else:
                current_content.append(line)
        if current_section and current_content:
            documents.extend(self._create_text_chunks(current_section, current_content, category))

        return documents

    def _create_text_chunks(self, section_name, content, category):
        """Dynamically split large text content into chunks."""
        text = "\n".join(content)
        text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
        chunks = text_splitter.split_text(text)
        return [
            Document(page_content=chunk, metadata={"category": category, "section": section_name, "type": "text"})
            for chunk in chunks
        ]

    def _create_table_chunk(self, section_name, table_lines, category):
        """Store the entire table as a single chunk."""
        table = "\n".join(table_lines)
        return Document(page_content=table, metadata={"category": category, "section": section_name, "type": "table"})

    def _create_event_chunk(self, section_name, event_content, category):
        """Store the entire event as a single chunk."""
        event_text = f"Title: {event_content['Title']}\nDate & Time: {event_content['Date & Time']}\nLocation: {event_content['Location']}\nDescription: {event_content['Description']}"
        return Document(page_content=event_text, metadata={"category": category, "section": section_name, "type": "event"})

categories = {
    "General_Info_and_History_of_Pittsburgh_CMU": [
        "data/history_wiki_1.txt",
        "data/history_wiki_2.txt",
        "data/britannica.txt",
        "data/about_cmu_and_cmu_history.txt"
    ],
    "Events_in_Pittsburgh_and_CMU": [
        "data/city_paper.txt",
        "data/event_cal.txt",
        "data/downtown_cal.txt",
        "data/cmu_campus_major_events.txt",
        "data/events_cmu.txt"
    ],
    "Music_and_Culture": [
        "data/more.txt",
        "data/little_italy_days.txt",
        "data/picklesburgh.txt",
        "data/pittsburg_restauratnt_week.txt",
        "data/pittsburgh_taco_festival.txt",
        "data/banana_split_fest.txt",
        "data/pittsburgh_symphony.txt"
    ],
    "Sports": []  
}

name_mappings = {
    "data/history_wiki_1.txt": "Pittsburgh",
    "data/history_wiki_2.txt": "History of Pittsburgh",
    "data/britannica.txt": "Encyclopedia Brittanica page",
    "data/city_paper.txt": "Pittsburgh City Paper events",
    "data/event_cal.txt": "Pittsburgh events calendar",
    "data/downtown_cal.txt": "Downtown Pittsburgh events calendar",
    "data/more.txt": "more",
    "data/little_italy_days.txt":"Little Italy Days",
    "data/picklesburgh.txt":"Picklesburgh",
    "data/pittsburg_restauratnt_week.txt":"Pittsburg Restauratnt Week",
    "data/pittsburgh_taco_festival.txt":"Pittsburgh Taco Festival",
    "data/banana_split_fest.txt": "Banana Split Fest",
    "data/about_cmu_and_cmu_history.txt":"About CMU and CMU history",
    "data/pittsburgh_symphony.txt": "Pittsburgh Symphony",
    "data/events_cmu.txt": "CMU Event Calendar 2024",
    "data/cmu_campus_major_events.txt": "CMU Major Events 2025"
}

loader = DynamicHierarchicalTextLoader(categories, name_mappings)
all_documents = loader.load()

# %% [markdown]
# ### Check if loader correclty loaded and chunked the data

# %%
def print_every_20th_document(documents, stop_at=400, interval=20):
    print(f"Total number of documents: {len(documents)}\n")
    
    for i in range(0, min(stop_at, len(documents)), interval):
        doc = documents[i]
        print(f"Document {i+1}:")
        print(f"Content (snippet): {doc.page_content}") 
        print("Metadata:")
        for key, value in doc.metadata.items():
            print(f"  {key}: {value}")
        print("\n" + "-"*60 + "\n")

print_every_20th_document(all_documents, stop_at=400, interval=20)
# Out:
# Total number of documents: 1029
#
# Document 1:
# Content (snippet): Table Name: Pittsburgh
# +------------------------------+------------------------------+
# |City                          |                              |
# +------------------------------+------------------------------+
# |Downtown PittsburghMexican War|                              |
# +------------------------------+------------------------------+
# |FlagSealCoat of arms          |                              |
# +------------------------------+------------------------------+
# |Nicknames: City of Bridges, St|                              |
# +------------------------------+------------------------------+
# |Motto: Benigno Numine ("With t|                              |
# +------------------------------+------------------------------+
# |Interactive map of Pittsburgh |                              |
# +------------------------------+------------------------------+
# |PittsburghShow map of Pennsylv|                              |
# +------------------------------+------------------------------+
# |Coordinates: 40°26′23″N 79°58′|                              |
# +------------------------------+------------------------------+
# |Country                       |United States                 |
# +------------------------------+------------------------------+
# |State                         |Pennsylvania                  |
# +------------------------------+------------------------------+
# |County                        |Allegheny                     |
# +------------------------------+------------------------------+
# |Founded                       |November 27, 1758; 265 years a|
# +------------------------------+------------------------------+
# |Municipal incorporation       |April 22, 1794; 230 years ago |
# +------------------------------+------------------------------+
# |Founded by                    |John Forbes                   |
# +------------------------------+------------------------------+
# |Named for                     |William Pitt, 1st Earl of Chat|
# +------------------------------+------------------------------+
# |Government                    |                              |
# +------------------------------+------------------------------+
# |• Type                        |Mayor-council                 |
# +------------------------------+------------------------------+
# |• Mayor                       |Ed Gainey (D)                 |
# +------------------------------+------------------------------+
# |• City Council                |List Bobby WilsonTheresa Kail-|
# +------------------------------+------------------------------+
# |Area[1]                       |                              |
# +------------------------------+------------------------------+
# |• City                        |58.35 sq mi (151.12 km2)      |
# +------------------------------+------------------------------+
# |• Land                        |55.38 sq mi (143.42 km2)      |
# +------------------------------+------------------------------+
# |• Water                       |2.97 sq mi (7.70 km2)         |
# +------------------------------+------------------------------+
# |Highest elevation             |1,370 ft (420 m)              |
# +------------------------------+------------------------------+
# |Lowest elevation              |710 ft (220 m)                |
# +------------------------------+------------------------------+
# |Population (2020)[2]          |                              |
# +------------------------------+------------------------------+
# |• City                        |302,971                       |
# +------------------------------+------------------------------+
# |• Rank                        |68th in the United States2nd i|
# +------------------------------+------------------------------+
# |• Density                     |5,471.26/sq mi (2,112.47/km2) |
# +------------------------------+------------------------------+
# |• Urban                       |1,745,039 (US: 30th)          |
# +------------------------------+------------------------------+
# |• Urban density               |1,924.7/sq mi (743.1/km2)     |
# +------------------------------+------------------------------+
# |• Metro[3][4]                 |2,457,000 (US: 26th)          |
# +------------------------------+------------------------------+
# |Demonym(s)                    |Pittsburgher, Yinzer          |
# +------------------------------+------------------------------+
# |GDP[5]                        |                              |
# +------------------------------+------------------------------+
# |• Pittsburgh (MSA)            |$153.3 billion (2022)         |
# +------------------------------+------------------------------+
# |Time zone                     |UTC−5 (Eastern Standard Time) |
# +------------------------------+------------------------------+
# |• Summer (DST)                |UTC−4 (Eastern Daylight Time) |
# +------------------------------+------------------------------+
# |ZIP Code                      |76 total ZIP codes: 15122, 152|
# +------------------------------+------------------------------+
# |Area codes                    |412, 724, 878                 |
# +------------------------------+------------------------------+
# |FIPS code                     |42-61000                      |
# +------------------------------+------------------------------+
# |GNIS feature ID               |1213644                       |
# +------------------------------+------------------------------+
# |Website                       |pittsburghpa.gov              |
# +------------------------------+------------------------------+
# |                              |                              |
# +------------------------------+------------------------------+
# |Pennsylvania Historical Marker|                              |
# +------------------------------+------------------------------+
# |Designated                    |1946[6]                       |
# +------------------------------+------------------------------+
# |                              |                              |
# +------------------------------+------------------------------+
# |                              |                              |
# +------------------------------+------------------------------+
# Metadata:
#   category: General_Info_and_History_of_Pittsburgh_CMU
#   section: Pittsburgh: Intro
#   type: table
#
# ------------------------------------------------------------
#
# Document 21:
# Content (snippet): During World War II, demand for steel increased and area mills operated 24 hours a day to produce 95 million tons of steel for the war effort.[29] This resulted in the highest levels of air pollution in the city's almost century of industry. The city's reputation as the "arsenal of democracy"[47][48] was being overshadowed by James Parton's 1868 observation of Pittsburgh being "hell with the lid off."[49]
# Following World War II, the city launched a clean air and civic revitalization project known as the "Renaissance," cleaning up the air and the rivers. The "Renaissance II" project followed in 1977, focused on cultural and neighborhood development. The industrial base continued to expand through the 1970s, but beginning in the early 1980s both the area's steel and electronics industries imploded during national industrial restructuring. There were massive layoffs from mill and plant closures.[11]
# Metadata:
#   category: General_Info_and_History_of_Pittsburgh_CMU
#   section: Pittsburgh: 20th century
#   type: text
#
# ------------------------------------------------------------
#
# Document 41:
# Content (snippet): Under the Köppen climate classification, Pittsburgh falls within either a hot-summer humid continental climate (Dfa) if the 0 °C (32 °F) isotherm is used or a humid subtropical climate (Cfa) if the −3 °C (27 °F) isotherm is used. Summers are hot and winters are moderately cold with wide variations in temperature. Despite this, it has one of the most pleasant summer climates between medium and large cities in the U.S.[71][72][73] The city lies in the USDA plant hardiness zone 6b except along the rivers where the zone is 7a.[74] The area has four distinct seasons: winters are cold and snowy, springs and falls are mild with moderate levels of sunshine, and summers are warm. As measured by percent possible sunshine, summer is by far the sunniest season, though annual sunshine is low among major US cities at well under 50%.[75]
# Metadata:
#   category: General_Info_and_History_of_Pittsburgh_CMU
#   section: Pittsburgh: Climate
#   type: text
#
# ------------------------------------------------------------
#
# Document 61:
# Content (snippet): Table Name: Religion in Pittsburgh (2014)[133]
# +---------------+-------+
# |Religion       |Percent|
# +---------------+-------+
# |Protestantism  |42%    |
# +---------------+-------+
# |Catholicism    |32%    |
# +---------------+-------+
# |Other Christian|3%     |
# +---------------+-------+
# |No religion    |18%    |
# +---------------+-------+
# |Others         |4%     |
# +---------------+-------+
# |Don't know     |1%     |
# +---------------+-------+
# Metadata:
#   category: General_Info_and_History_of_Pittsburgh_CMU
#   section: Pittsburgh: 2020 census
#   type: table
#
# ------------------------------------------------------------
#
# Document 81:
# Content (snippet): The largest employer in the city is the University of Pittsburgh Medical Center, with 48,000 employees. All hospitals, outpatient clinics, and doctor's office positions combine for 116,000 jobs, approximately 10% of the jobs in the region. An analyst recently observed of the city's medical sector: "That's both more jobs and a higher share of the region's total employment than the steel industry represented in the 1970s."[154]
# Education is a major economic driver in the region. The largest single employer in education is the University of Pittsburgh, with 10,700 employees.[155]
# Metadata:
#   category: General_Info_and_History_of_Pittsburgh_CMU
#   section: Pittsburgh: Economy
#   type: text
#
# ------------------------------------------------------------
#
# Document 101:
# Content (snippet): the University of Pittsburgh, where he is a faculty member. Poet Michael Simms, founder of Autumn House Press, resides in the Mount Washington neighborhood of Pittsburgh. Poet Samuel John Hazo, the first poet Laureate of Pennsylvania, resides in the city. Contemporary writers from Pittsburgh include Kathleen Tessaro, author of novels such as "Elegance," "The Perfume Collector," and "Rare Objects," whose works contribute to the city's rich literary tradition. New writers include Chris Kuzneski, who attended the University of Pittsburgh and mentions Pittsburgh in his works, and Pittsburgher Brian Celio, author of Catapult Soul, who captured the Pittsburgh 'Yinzer' dialect in his writing. Pittsburgh's unique literary style extends to playwrights,[191] as well as local graffiti and hip hop artists.
# Metadata:
#   category: General_Info_and_History_of_Pittsburgh_CMU
#   section: Pittsburgh: Literature
#   type: text
#
# ------------------------------------------------------------
#
# Document 121:
# Content (snippet): Acrisure Stadium serves as home for the Steelers, Panthers, and both the suburban and city high school championships. Playoff franchises Pittsburgh Power and Pittsburgh Gladiators competed in the Arena Football League in the 1980s and 2010s respectively. The Gladiators hosted ArenaBowl I in the city, competing in two, but losing both before moving to Tampa, Florida and becoming the Storm.[226] The Pittsburgh Passion has been the city's professional women's football team since 2002 and plays its home games at Highmark Stadium. The Ed Debartolo owned Pittsburgh Maulers featured a Heisman Trophy winner in the mid-1980s, former superstar University of Nebraska running back Mike Rozier.
# Metadata:
#   category: General_Info_and_History_of_Pittsburgh_CMU
#   section: Pittsburgh: Football
#   type: text
#
# ------------------------------------------------------------
#
# Document 141:
# Content (snippet): Pittsburgh is home to many colleges, universities and research facilities, the most well-known of which are Carnegie Mellon University, the University of Pittsburgh, and Duquesne University. Also in the city are Carlow University, Chatham University, Point Park University, the Community College of Allegheny County, Pittsburgh Theological Seminary, Reformed Presbyterian Theological Seminary, and the Pittsburgh Institute of Mortuary Science.
# The campuses of Carlow, Carnegie Mellon, and the University of Pittsburgh are near each other in the Oakland neighborhood that is the city's traditional cultural center. Carnegie Mellon University (CMU) is a private research university founded by Andrew Carnegie and Andrew Mellon.[252] CMU contains the Mellon College of Science, School of Computer Science, College of Engineering, School of Business, Heinz College, College of Fine Arts, writing, Social and Decision Sciences, information systems, statistics, and psychology programs.
# Metadata:
#   category: General_Info_and_History_of_Pittsburgh_CMU
#   section: Pittsburgh: Colleges and universities
#   type: text
#
# ------------------------------------------------------------
#
# Document 161:
# Content (snippet): Table Name: Expressways and highways
# +-----------+---------------------------+----------+------+
# |Expressways|Other Highways             |          |      |
# +-----------+---------------------------+----------+------+
# |           |Parkway North              |US 19     |PA 88 |
# +-----------+---------------------------+----------+------+
# |           |Parkway East & West        |TruckUS 19|PA 121|
# +-----------+---------------------------+----------+------+
# |           |Crosstown                  |PA 8      |PA 130|
# +-----------+---------------------------+----------+------+
# |           |Allegheny Valley Expressway|PA 50     |PA 380|
# +-----------+---------------------------+----------+------+
# |           |Ohio River Boulevard       |PA 51     |PA 837|
# +-----------+---------------------------+----------+------+
# |           |                           |PA 60     |PA 885|
# +-----------+---------------------------+----------+------+
# Metadata:
#   category: General_Info_and_History_of_Pittsburgh_CMU
#   section: Pittsburgh: Expressways and highways
#   type: table
#
# ------------------------------------------------------------
#
# Document 181:
# Content (snippet): Governor Dinwiddie sent Captain William Trent to build a fort at the Forks of the Ohio. On February 17, 1754, Trent began construction of the fort, the first European habitation[17] at the site of present-day Pittsburgh. The fort, named Fort Prince George, was only half-built by April 1754, when over 500 French forces arrived and ordered the 40-some colonials back to Virginia. The French tore down the British fortification and constructed Fort Duquesne.[14][15]
# Metadata:
#   category: General_Info_and_History_of_Pittsburgh_CMU
#   section: History of Pittsburgh: Early colonization (1747–1763)
#   type: text
#
# ------------------------------------------------------------
#
# Document 201:
# Content (snippet): - using 400 steam engines
# - Total coal consumed — 22M bushels
# - Total iron consumed — 127K tons
# - In steam tonnage, third busiest port in the nation, surpassed only by New York City and New Orleans.
# - employing more than 10K workers
# - producing almost $12M in goods
# - using 400 steam engines
# Metadata:
#   category: General_Info_and_History_of_Pittsburgh_CMU
#   section: History of Pittsburgh: Iron City (1800–1859)
#   type: text
#
# ------------------------------------------------------------
#
# Document 221:
# Content (snippet): On March 17 and 18, 1936, Pittsburgh suffered the worst flood in its history, with flood levels peaking at 46 feet. This catastrophe killed 69 victims, destroyed thousands of buildings, caused $3B (2006 dollars) in damages, and put more than 60,000 steelworkers out of work.[57]
# Metadata:
#   category: General_Info_and_History_of_Pittsburgh_CMU
#   section: History of Pittsburgh: Environment
#   type: text
#
# ------------------------------------------------------------
#
# Document 241:
# Content (snippet): In 1991 the Homestead Works was demolished, replaced in 1999 by The Waterfront shopping mall. As a direct result of the loss of mill employment, the number of people living in Homestead dwindled. By the time of the 2000 census, the borough population was 3,569. The borough began financially recovering in 2002, with the enlarging retail tax base.
# Metadata:
#   category: General_Info_and_History_of_Pittsburgh_CMU
#   section: History of Pittsburgh: Collapse of steel
#   type: text
#
# ------------------------------------------------------------
#
# Document 261:
# Content (snippet): 1 of 2
# William C. Wall: View of the Great Fire of PittsburghView of the Great Fire of Pittsburgh, oil on canvas by William C. Wall, 1846; in the Carnegie Museum of Art, Pittsburgh, Pa. 51 × 81 cm.(more)
# 2 of 2
# Pittsburgh: steel mill, 1886Bessemer converters in operation at a steel mill in Pittsburgh, 1886.(more)
# Metadata:
#   category: General_Info_and_History_of_Pittsburgh_CMU
#   section: Encyclopedia Brittanica page: History
#   type: text
#
# ------------------------------------------------------------
#
# Document 281:
# Content (snippet): Title: Hard Day's Night The Beatles Tribute
# Date & Time: Sat., Oct. 12, 8-10:30 p.m.
# Location: 222 Main Street, Irwin
# Description: Location 1: The Lamp Theatre
# Price: 32
# Type of Event: Rock
# Description: On sale Friday, July 12 @10am! Visit https://www.lamptheatre.org/hard-days-night or call 724-367-4000 to purchase.
# Since 1996, Hard Day's Night has been entertaining Beatles fans across the country. Hailing from the rock 'n roll city of Cleveland, Ohio, Hard Day's Night is rated among the top national Beatles tribute groups performing today. The band focuses on performing songs exactly as the Beatles themselves did; four musicians onstage in character as John, Paul, George, and Ringo; wearing perfect stitch-for-stitch replications of the suits made famous by the Beatles; with authentic Vox, Hofner, Gretsch, Rickenbacker, and Ludwig instruments; playing the world-famous songs note-for-note.
# #lamptheate
# 724-367-4000
#
# Metadata:
#   category: Events_in_Pittsburgh_and_CMU
#   section: Pittsburgh City Paper events: Pittsburgh City Paper events
#   type: event
#
# ------------------------------------------------------------
#
# Document 301:
# Content (snippet): Title: Nasty Slam
# Date & Time: First Wednesday of every month, 10-11:45 p.m.
# Location: 242 51st St., Pittsburgh
# Description: Location 1: Spirit Hall & Lodge
# Price: $10 to watch, $10 to play
# Type of Event: Literary
# Description: Cheer on local writers during the latest Nasty Slam, a live poetry contest at Spirit where the winner is determined by audience applause. Bring three poems, your friends, and a willingness to fight dirty with your most ill-mannered, aggressive, take-no-prisoners attitude. The triumphant will take home a $200 cash prize and the prestige of being one of Pittsburgh’s nastiest poets.
# 412-586-4441
#
# Metadata:
#   category: Events_in_Pittsburgh_and_CMU
#   section: Pittsburgh City Paper events: Pittsburgh City Paper events
#   type: event
#
# ------------------------------------------------------------
#
# Document 321:
# Content (snippet): Location: 303 Pearce Mill Road, Allison Park
# Price: Free: USD 0.00
# Type of Event: Community
# Description: Get to know more about North Park and the work of the Allegheny County Parks Foundation by attending free activities on October 12. Activities are for individuals or groups of all ages and abilities!
# 724-327-7627
# Title: Guardian Storage Fall 2024 Free Shred-It Event
# Date & Time: Sat., Oct. 12, 11 a.m.-2 p.m.
# Location 1: Multiple Guardian Storage Locations
# Location: 1300 Lebanon Church Rd., Pleasant Hills
# Price: Free
# Type of Event: Other Stuff
# Metadata:
#   category: Events_in_Pittsburgh_and_CMU
#   section: Pittsburgh City Paper events: Pittsburgh City Paper events
#   type: text
#
# ------------------------------------------------------------
#
# Document 341:
# Content (snippet): Date & Time: First Wednesday of every month, 6:30-9 p.m.
# Location 1: Eleventh Hour Brewing Co
# Location: 3711 Charlotte Street, Pittsburgh
# Price: Attendance is Free
# Type of Event: Visual Art, Community
# Description: Welcome to Knit PIT Yarn Club, a meetup for knitters of all levels! Tap into your creativity and have fun while crafting with others. Join us to learn new skills, share patterns, and make friends. Whether you're knitting your first scarf or your 25th sweater, you'll find inspiration, laughter, and good vibes. Come enjoy the crafty chaos — knitting is about the journey, not just the finished piece! We meet at Eleventh Hour Brewing on the first Wednesday of each month. We also offer workshops, lessons, and kits.
# (412)699-4074
# Title: Quantum Theatre’s The Cabinet of Dr. Caligari’s Quantum Quaff
# Date & Time: Thu., Nov. 7, 6:30 p.m.
# Location 1: Union Trust Building
# Location: 501 Grant St., Pittsburgh
# Price: $80
# Type of Event: Food & Drink Event, Theater
# Metadata:
#   category: Events_in_Pittsburgh_and_CMU
#   section: Pittsburgh City Paper events: Pittsburgh City Paper events
#   type: text
#
# ------------------------------------------------------------
#
# Document 361:
# Content (snippet): Title: Pittsburgh Symphony Orchestra
# Date & Time: Oct 18 2024 7:30 PM
# Location: 15222, Pittsburgh, PA, US
# Description: Arena: Heinz Hall
# Price: Prices from $127
#
# Metadata:
#   category: Events_in_Pittsburgh_and_CMU
#   section: Pittsburgh events calendar: Pittsburgh events calendar
#   type: event
#
# ------------------------------------------------------------
#
# Document 381:
# Content (snippet): Title: PPG Paints Arena Tours
# Date & Time: Oct 22 2024 10:00 AM
# Location: 15219, Pittsburgh, Pennsylvania, US
# Description: Arena: PPG Paints Arena
# Price: Prices from $39
#
# Metadata:
#   category: Events_in_Pittsburgh_and_CMU
#   section: Pittsburgh events calendar: Pittsburgh events calendar
#   type: event
#
# ------------------------------------------------------------

# %% [markdown]
# # Generate Embeddings and create a vectorized representation

# %%
embeddings = PineconeEmbeddings(model="multilingual-e5-large")
vector_store = Chroma.from_documents(
    documents=all_documents,
    embedding=embeddings,
    collection_name="my_vector_store"
)

# %%
model = ChatMistralAI(api_key=os.environ["MISTRAL_API_KEY"], model="mistral-large-latest")

# %%
prompt_template_retrieval = """
Answer the question in one sentence based on the context below.

Context:
{context}

Question:
{question}
"""
prompt_template_no_retrieval = """
    Answer the question in one sentence.

    Question:
    {question}
    """

# %% [markdown]
# ## Specify the question here

# %%
q = "Where will Geek Out Gala event will take place on October 17, 2024?"

# %% [markdown]
# ## LLM only (no retrieval)

# %%
response_no_retrieval = model.invoke(prompt_template_no_retrieval.format(
    question=q
))
print("LLM output without retrieval:")
print(response_no_retrieval.content)
# Out:
# LLM output without retrieval:
# The Geek Out Gala event will take place at the Hilton Hotel.

# %% [markdown]
# ## LLM + relevant retrieval

# %%
retrieved_documents = vector_store.as_retriever().get_relevant_documents(q)
retrieved_context = "\n".join([doc.page_content for doc in retrieved_documents])


response_with_retrieval = model.invoke(prompt_template_retrieval.format(
    context=retrieved_context,  
    question=q
))
print(response_with_retrieval.content)
# Out:
# The Geek Out Gala event will take place at the Carnegie Science Center, 1 Allegheny Ave Pittsburgh, PA 15212.

# %%
retrieved_documents
# Out:
# [Document(metadata={'category': 'Events_in_Pittsburgh_and_CMU', 'section': 'Pittsburgh events calendar: Pittsburgh events calendar', 'type': 'event'}, page_content='Title: W.A.S.P.\nDate & Time: Nov 20 2024 6:00 PM\nLocation: 15212, Pittsburgh, PA, US\nDescription: Arena: Stage AE\nPrice: Prices from $49\n'),
#  Document(metadata={'category': 'Events_in_Pittsburgh_and_CMU', 'section': 'Pittsburgh events calendar: Pittsburgh events calendar', 'type': 'event'}, page_content='Title: The Slaps\nDate & Time: Nov 12 2024 8:00 PM\nLocation: 15203, Pittsburgh, PA, US\nDescription: Arena: Club Cafe\nPrice: Prices from $32\n'),
#  Document(metadata={'category': 'Events_in_Pittsburgh_and_CMU', 'section': 'Pittsburgh events calendar: Pittsburgh events calendar', 'type': 'event'}, page_content='Title: Eliza McLamb\nDate & Time: Oct 30 2024 7:00 PM\nLocation: 15201, Pittsburgh, PA, US\nDescription: Arena: Spirit Hall\nPrice: Prices from $33\n'),
#  Document(metadata={'category': 'Events_in_Pittsburgh_and_CMU', 'section': 'Pittsburgh events calendar: Pittsburgh events calendar', 'type': 'event'}, page_content='Title: Nate Smith\nDate & Time: Nov 02 2024 7:00 PM\nLocation: 15212, Pittsburgh, PA, US\nDescription: Arena: Stage AE\nPrice: Prices from $33\n')]
